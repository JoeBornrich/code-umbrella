# %% [markdown]
# # DATA ANALYSIS

# %%
import pandas as pd

df = pd.read_excel('XX_Electronics.xlsx')
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date
# 0                 2.00 2022-02-01
# 1                 2.00 2022-02-01
# 2                 2.00 2022-06-01
# ...

# %%
df.dtypes
# Out:
# Countries                      object
# Products                       object
# Quantity                      float64
# Revenue per product             int64
# Cost per product              float64
# Order Date             datetime64[ns]
# dtype: object

# %%
df.head(5)
# Out:
#   Countries        Products  Quantity  Revenue per product  Cost per product  \
# 0   Nigeria  Type A Charger     292.0                    5               2.0
# 1     Ghana  Type A Charger     974.0                    5               2.0
# 2   Nigeria  Type A Charger    2518.0                    5               2.0
# 3     Kenya  Type A Charger    1006.0                    5               2.0
# 4     Kenya  Type A Charger     367.0                    5               2.0
#
#   Order Date
# 0 2022-02-01
# 1 2022-02-01
# 2 2022-06-01
# 3 2022-06-01
# 4 2022-07-01

# %%
df.tail(5)
# Out:
#          Countries     Products  Quantity  Revenue per product  \
# 1345        Zambia  Pin Charger     663.0                    6
# 1346  South Africa  Pin Charger    2574.0                    6
# 1347  South Africa  Pin Charger    2438.0                    6
# 1348  South Africa  Pin Charger     914.0                    6
# 1349  South Africa  Pin Charger     914.0                    6
#
#       Cost per product Order Date
# 1345              2.75 2022-09-01
# 1346              2.75 2021-11-01
# 1347              2.75 2021-12-01
# 1348              2.75 2022-12-01
# 1349              2.75 2022-12-01

# %%
df.shape
# Out:
# (1350, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Countries            1350 non-null   object
#  1   Products             1350 non-null   object
#  2   Quantity             1350 non-null   float64
#  3   Revenue per product  1350 non-null   int64
#  4   Cost per product     1350 non-null   float64
#  5   Order Date           1350 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 63.4+ KB

# %%
df.Countries
# Out:
# 0            Nigeria
# 1              Ghana
# 2            Nigeria
# 3              Kenya
# 4              Kenya
#             ...
# 1345          Zambia
# 1346    South Africa
# 1347    South Africa
# 1348    South Africa
# 1349    South Africa
# Name: Countries, Length: 1350, dtype: object

# %%
df['Products']
# Out:
# 0       Type A Charger
# 1       Type A Charger
# 2       Type A Charger
# 3       Type A Charger
# 4       Type A Charger
#              ...
# 1345       Pin Charger
# 1346       Pin Charger
# 1347       Pin Charger
# 1348       Pin Charger
# 1349       Pin Charger
# Name: Products, Length: 1350, dtype: object

# %%
df[['Countries', 'Products']]
# Out:
#          Countries        Products
# 0          Nigeria  Type A Charger
# 1            Ghana  Type A Charger
# 2          Nigeria  Type A Charger
# 3            Kenya  Type A Charger
# 4            Kenya  Type A Charger
# ...            ...             ...
# 1345        Zambia     Pin Charger
# 1346  South Africa     Pin Charger
# 1347  South Africa     Pin Charger
# 1348  South Africa     Pin Charger
# 1349  South Africa     Pin Charger
#
# [1350 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Countries                          Nigeria
# Products                    Type A Charger
# Quantity                             292.0
# Revenue per product                      5
# Cost per product                       2.0
# Order Date             2022-02-01 00:00:00
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Countries                            Ghana
# Products                    Type A Charger
# Quantity                             974.0
# Revenue per product                      5
# Cost per product                       2.0
# Order Date             2022-02-01 00:00:00
# Name: 1, dtype: object

# %%
df.iloc[100]
# Out:
# Countries                            Kenya
# Products                    Type A Charger
# Quantity                            3513.0
# Revenue per product                      5
# Cost per product                       2.0
# Order Date             2022-07-01 00:00:00
# Name: 100, dtype: object

# %%
df.iloc[0 : 3]
# Out:
#   Countries        Products  Quantity  Revenue per product  Cost per product  \
# 0   Nigeria  Type A Charger     292.0                    5               2.0
# 1     Ghana  Type A Charger     974.0                    5               2.0
# 2   Nigeria  Type A Charger    2518.0                    5               2.0
#
#   Order Date
# 0 2022-02-01
# 1 2022-02-01
# 2 2022-06-01

# %%
df.iloc[1,0]
# Out:
# 'Ghana'

# %%
df.iloc[2,2]
# Out:
# np.float64(2518.0)

# %%
df.sort_values('Countries')
# Out:
#     Countries        Products  Quantity  Revenue per product  \
# 620     Ghana     Pin Charger    2861.0                    6
# 237     Ghana  Type B Charger     720.0                    1
# 796     Ghana  Type A Charger    1984.0                    5
# 468     Ghana  Iphone Charger    2579.0                    4
# 233     Ghana  Type B Charger    1138.0                    1
# ..        ...             ...       ...                  ...
# 528    Zambia    Mini Charger    1738.5                    3
# 532    Zambia    Mini Charger     959.0                    3
# 534    Zambia    Mini Charger     574.5                    3
# 546    Zambia    Mini Charger    2234.0                    3
# 674    Zambia     Pin Charger    2805.0                    6
#
#      Cost per product Order Date
# 620              2.75 2022-01-01
# 237              0.20 2021-09-01
# 796              2.00 2022-08-01
# 468              1.50 2022-04-01
# 233              0.20 2022-12-01
# ...

# %%
df.sort_values('Countries', ascending = False)
# Out:
#      Countries        Products  Quantity  Revenue per product  \
# 671     Zambia     Pin Charger     853.0                    6
# 1196    Zambia    Mini Charger    1227.0                    3
# 244     Zambia  Type B Charger    1757.0                    1
# 853     Zambia  Type B Charger    1899.0                    1
# 242     Zambia  Type B Charger    1403.0                    1
# ...        ...             ...       ...                  ...
# 237      Ghana  Type B Charger     720.0                    1
# 1110     Ghana  Iphone Charger    2156.0                    4
# 239      Ghana  Type B Charger    1100.0                    1
# 1108     Ghana  Iphone Charger     886.0                    4
# 675      Ghana     Pin Charger     655.0                    6
#
#       Cost per product Order Date
# 671               2.75 2022-12-01
# 1196              1.25 2022-10-01
# 244               0.20 2021-10-01
# 853               0.20 2022-06-01
# 242               0.20 2021-10-01
# ...

# %%
df.sort_values(['Countries', 'Quantity'])
# Out:
#      Countries        Products  Quantity  Revenue per product  \
# 654      Ghana     Pin Charger     245.0                    6
# 1303     Ghana     Pin Charger     245.0                    6
# 180      Ghana  Type A Charger     260.0                    5
# 829      Ghana  Type A Charger     260.0                    5
# 552      Ghana    Mini Charger     341.0                    3
# ...        ...             ...       ...                  ...
# 15      Zambia  Type A Charger    3945.0                    5
# 681     Zambia     Pin Charger    3997.5                    6
# 1330    Zambia     Pin Charger    3997.5                    6
# 410     Zambia  Iphone Charger    4243.5                    4
# 1059    Zambia  Iphone Charger    4243.5                    4
#
#       Cost per product Order Date
# 654               2.75 2022-05-01
# 1303              2.75 2022-05-01
# 180               2.00 2022-02-01
# 829               2.00 2022-02-01
# 552               1.25 2022-05-01
# ...

# %%
df.sort_values(['Countries', 'Quantity'], ascending= [1,0])
# Out:
#      Countries        Products  Quantity  Revenue per product  \
# 118      Ghana  Type A Charger    2993.0                    5
# 767      Ghana  Type A Charger    2993.0                    5
# 577      Ghana    Mini Charger    2903.0                    3
# 1226     Ghana    Mini Charger    2903.0                    3
# 620      Ghana     Pin Charger    2861.0                    6
# ...        ...             ...       ...                  ...
# 285     Zambia  Type B Charger     293.0                    1
# 589     Zambia    Mini Charger     293.0                    3
# 849     Zambia  Type A Charger     293.0                    5
# 934     Zambia  Type B Charger     293.0                    1
# 1238    Zambia    Mini Charger     293.0                    3
#
#       Cost per product Order Date
# 118               2.00 2022-09-01
# 767               2.00 2022-09-01
# 577               1.25 2022-03-01
# 1226              1.25 2022-03-01
# 620               2.75 2022-01-01
# ...

# %%
df.loc[df["Countries"] =="Nigeria"]
# Out:
#      Countries        Products  Quantity  Revenue per product  \
# 0      Nigeria  Type A Charger     292.0                    5
# 2      Nigeria  Type A Charger    2518.0                    5
# 10     Nigeria  Type A Charger    1725.0                    5
# 12     Nigeria  Type A Charger    2152.0                    5
# 13     Nigeria  Type A Charger    1817.0                    5
# ...        ...             ...       ...                  ...
# 1319   Nigeria     Pin Charger    1916.0                    6
# 1321   Nigeria     Pin Charger     384.0                    6
# 1326   Nigeria     Pin Charger    1808.0                    6
# 1331   Nigeria     Pin Charger    2632.0                    6
# 1341   Nigeria     Pin Charger     269.0                    6
#
#       Cost per product Order Date
# 0                 2.00 2022-02-01
# 2                 2.00 2022-06-01
# 10                2.00 2021-11-01
# 12                2.00 2021-12-01
# 13                2.00 2022-12-01
# ...

# %%
df['Revenue'] = df['Quantity'] * df['Revenue per product']

# %%
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue
# 0                 2.00 2022-02-01   1460.0
# 1                 2.00 2022-02-01   4870.0
# ...

# %%
df['Total cost'] = df['Quantity'] * df['Cost per product']

# %%
df['Profit'] = df['Revenue'] - df['Total cost']

# %%
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue  Total cost   Profit
# 0                 2.00 2022-02-01   1460.0      584.00   876.00
# ...

# %%
df.to_excel('Analysis1_output.xlsx')

# %%
df.to_excel('Analysis1_output.xlsx', index = False)

# %%
df['mon1'] = df['Order Date'] .dt.strftime('%m')
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue  Total cost   Profit mon1
# 0                 2.00 2022-02-01   1460.0      584.00   876.00   02
# ...

# %%
df['mon1'] = df['Order Date'] .dt.month
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue  Total cost   Profit  mon1
# 0                 2.00 2022-02-01   1460.0      584.00   876.00     2
# ...

# %%
df['mon1'] = df['Order Date'] .dt.strftime('%y/%m/%d')
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue  Total cost   Profit      mon1
# 0                 2.00 2022-02-01   1460.0      584.00   876.00  22/02/01
# ...

# %%
df['mon1'] = df['Order Date'] .dt.year
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue  Total cost   Profit  mon1
# 0                 2.00 2022-02-01   1460.0      584.00   876.00  2022
# ...

# %%
df['mon2'] = df['Order Date'] .apply(lambda y: y.strftime('%B'))
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue  Total cost   Profit  mon1  \
# 0                 2.00 2022-02-01   1460.0      584.00   876.00  2022
# ...

# %%
df['mon2'] = df['Order Date'] .apply(lambda y: y.strftime('%b/%y'))
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenue  Total cost   Profit  mon1    mon2
# 0                 2.00 2022-02-01   1460.0      584.00   876.00  2022  Feb/22
# ...

# %% [markdown]
# # DATE FUNTIONS

# %%
df['mon2'] = df['Order Date'] .apply(lambda y: y.strftime('%B'))
df
