# %%
import pandas as pd

df = pd.read_excel('RSC.xlsx')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
del df['Status']

# %%
del df['unnamed1']

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df['Gender'] = df['Gender'].str.replace('M', 'Male')

# %%
df['Gender'] = df['Gender'].str.replace('F', 'Male')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942   Male     26-35   28               0
# 1      1000732       Kartik  P00110942   Male     26-35   35               1
# 2      1001990        Bindu  P00118542   Male     26-35   35               1
# 3      1001425       Sudevi  P00237842   Male      0-17   16               0
# 4      1000588         Joni  P00057942   Male     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942   Male     18-25   19               1
# 11247  1004089  Reichenbach  P00171342   Male     26-35   33               0
# 11248  1001209        Oshin  P00201342   Male     36-45   40               0
# 11249  1004023       Noonan  P00059442   Male     36-45   37               0
# 11250  1002744      Brumley  P00281742   Male     18-25   19               0
#
# ...

# %%
df['Marital_Status'] = df['Marital_Status'].astype(str)
df['Marital_Status'] = df['Marital_Status'].str.replace('0', 'Single')
df['Marital_Status'] = df['Marital_Status'].str.replace('1', 'Married')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age Marital_Status  \
# 0      1002903    Sanskriti  P00125942   Male     26-35   28         Single
# 1      1000732       Kartik  P00110942   Male     26-35   35        Married
# 2      1001990        Bindu  P00118542   Male     26-35   35        Married
# 3      1001425       Sudevi  P00237842   Male      0-17   16         Single
# 4      1000588         Joni  P00057942   Male     26-35   28        Married
# ...        ...          ...        ...    ...       ...  ...            ...
# 11246  1000695      Manning  P00296942   Male     18-25   19        Married
# 11247  1004089  Reichenbach  P00171342   Male     26-35   33         Single
# 11248  1001209        Oshin  P00201342   Male     36-45   40         Single
# 11249  1004023       Noonan  P00059442   Male     36-45   37         Single
# 11250  1002744      Brumley  P00281742   Male     18-25   19         Single
#
# ...

# %%
df['Amount'] = df['Amount'].fillna(0)
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age Marital_Status  \
# 0      1002903    Sanskriti  P00125942   Male     26-35   28         Single
# 1      1000732       Kartik  P00110942   Male     26-35   35        Married
# 2      1001990        Bindu  P00118542   Male     26-35   35        Married
# 3      1001425       Sudevi  P00237842   Male      0-17   16         Single
# 4      1000588         Joni  P00057942   Male     26-35   28        Married
# ...        ...          ...        ...    ...       ...  ...            ...
# 11246  1000695      Manning  P00296942   Male     18-25   19        Married
# 11247  1004089  Reichenbach  P00171342   Male     26-35   33         Single
# 11248  1001209        Oshin  P00201342   Male     36-45   40         Single
# 11249  1004023       Noonan  P00059442   Male     36-45   37         Single
# 11250  1002744      Brumley  P00281742   Male     18-25   19         Single
#
# ...

# %%
df['Cust_name'].nunique()
# Out:
# 1250

# %%
dff = df. pivot_table(index = 'Occupation',
                 values = 'Orders',
                 aggfunc = 'sum')
          # margins = 'Grand Total' )
dft = dff
dft
# Out:
#                  Orders
# Occupation
# Agriculture         722
# All               28007
# Automobile         1373
# Aviation           3215
# Banking            2819
# Chemical           1310
# Construction       1025
# Food Processing    1073
# Govt               2155
# Healthcare         3455
# Hospitality        1746
# IT Sector          4010
# Lawyer             1344
# Media              1596
# Retail             1270
# Textile             894

# %%
dft = dft. pivot_table(index = 'Occupation',
                 values = 'Orders',
                 aggfunc = 'sum')
          
dft.sort_values(by=['Occupation'], ascending = False)
# Out:
#                  Orders
# Occupation
# Textile             894
# Retail             1270
# Media              1596
# Lawyer             1344
# IT Sector          4010
# Hospitality        1746
# Healthcare         3455
# Govt               2155
# Food Processing    1073
# Construction       1025
# Chemical           1310
# Banking            2819
# Aviation           3215
# Automobile         1373
# All               28007
# Agriculture         722

# %%
df = df. pivot_table(index = 'Occupation',
                 values = 'Orders',
                 aggfunc = 'sum')
          
df.sort_values(by=['Orders'], ascending = False)
# Out:
#                  Orders
# Occupation
# All               28007
# IT Sector          4010
# Healthcare         3455
# Aviation           3215
# Banking            2819
# Govt               2155
# Hospitality        1746
# Media              1596
# Automobile         1373
# Lawyer             1344
# Chemical           1310
# Retail             1270
# Food Processing    1073
# Construction       1025
# Textile             894
# Agriculture         722

# %%
df = df. pivot_table(index = 'Product_Category',
                 values = 'Amount',
                 aggfunc = 'sum')
          
df.sort_values(by=['Amount'], ascending = False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df = df. pivot_table(index = 'Product_Category',
#       2                  values = 'Amount',
#       3                  aggfunc = 'sum')
#       5 df.sort_values(by=['Amount'], ascending = False).head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9516, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9499 @Substitution("")
#    9500 @Appender(_shared_docs["pivot_table"])
#    9501 def pivot_table(
#    (...)
#    9512     sort: bool = True,
#    9513 ) -> DataFrame:
#    9514     from pandas.core.reshape.pivot import pivot_table
# -> 9516     return pivot_table(
#    9517         self,
#    9518         values=values,
#    9519         index=index,
#    9520         columns=columns,
# ...
