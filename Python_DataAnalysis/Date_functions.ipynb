# %% [markdown]
# # DATE

# %%
import pandas as pd

df = pd.read_excel('AR Data1.xlsx')
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit
# 0                 2.00 2022-02-01    1460.0   584.00   876.00
# ...

# %%
df['mon1'] = df['Order Date'] .dt.year
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1
# 0                 2.00 2022-02-01    1460.0   584.00   876.00  2022
# ...

# %%
df['mon2'] = df['Order Date'] .apply(lambda y: y.strftime('%b/%y'))
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1    mon2
# 0                 2.00 2022-02-01    1460.0   584.00   876.00  2022  Feb/22
# ...

# %%
df.query("Products == 'Pin Charger' ")
# Out:
#          Countries     Products  Quantity  Revenue per product  \
# 591          Ghana  Pin Charger    1493.0                    6
# 592         Zambia  Pin Charger    1804.0                    6
# 593          Kenya  Pin Charger    2161.0                    6
# 594          Kenya  Pin Charger    1006.0                    6
# 595          Kenya  Pin Charger    1545.0                    6
# ...            ...          ...       ...                  ...
# 1345        Zambia  Pin Charger     663.0                    6
# 1346  South Africa  Pin Charger    2574.0                    6
# 1347  South Africa  Pin Charger    2438.0                    6
# 1348  South Africa  Pin Charger     914.0                    6
# 1349  South Africa  Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1    mon2
# 591               2.75 2022-01-01    8958.0  4105.75  4852.25  2022  Jan/22
# ...

# %%
df.query("Products != 'Pin Charger' ")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1235         Kenya    Mini Charger    1175.0                    3
# 1236       Nigeria    Mini Charger    2954.0                    3
# 1237         Kenya    Mini Charger     552.0                    3
# 1238        Zambia    Mini Charger     293.0                    3
# 1239  South Africa    Mini Charger    1806.0                    3
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1    mon2
# 0                 2.00 2022-02-01    1460.0   584.00   876.00  2022  Feb/22
# ...

# %%
df.query("Products in ('Type A Charger', 'Pin Charger') ")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1    mon2
# 0                 2.00 2022-02-01    1460.0   584.00   876.00  2022  Feb/22
# ...

# %%
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1    mon2
# 0                 2.00 2022-02-01    1460.0   584.00   876.00  2022  Feb/22
# ...

# %%
df.query("Profit >= 1000  ")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# 5            Ghana  Type A Charger     883.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1    mon2
# 1                 2.00 2022-02-01    4870.0  1948.00  2922.00  2022  Feb/22
# ...

# %%
df.query("Profit >= 2000  and Profit <= 7000 " )
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 1            Ghana  Type A Charger     974.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 5            Ghana  Type A Charger     883.0                    5
# 7            Ghana  Type A Charger     788.0                    5
# 9     South Africa  Type A Charger    1143.0                    5
# ...            ...             ...       ...                  ...
# 1337         Kenya     Pin Charger    1013.0                    6
# 1338         Ghana     Pin Charger    1575.0                    6
# 1345        Zambia     Pin Charger     663.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1    mon2
# 1                 2.00 2022-02-01    4870.0  1948.00  2922.00  2022  Feb/22
# ...

# %%
df.query("`Order Date` >= '2022-02-01' and `Order Date` <= '2022-05-31'")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 16          Zambia  Type A Charger    2296.0                    5
# 17          Zambia  Type A Charger    1030.0                    5
# 18    South Africa  Type A Charger    1514.0                    5
# ...            ...             ...       ...                  ...
# 1313  South Africa     Pin Charger     790.0                    6
# 1338         Ghana     Pin Charger    1575.0                    6
# 1339  South Africa     Pin Charger     606.0                    6
# 1343         Ghana     Pin Charger     500.0                    6
# 1344        Zambia     Pin Charger    2826.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1    mon2
# 0                 2.00 2022-02-01    1460.0   584.00   876.00  2022  Feb/22
# ...

# %%
df['mon2'] = df['Order Date'] .apply(lambda y: y.strftime('%B'))
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1       mon2
# 0                 2.00 2022-02-01    1460.0   584.00   876.00  2022   February
# ...

# %%
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1    mon2
# 0                 2.00 2022-02-01    1460.0   584.00   876.00  2022  Feb/22
# ...

# %%
df[df["mon2"].str.contains('mber')]
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 6           Zambia  Type A Charger     549.0                    5
# 7            Ghana  Type A Charger     788.0                    5
# 8            Ghana  Type A Charger    2472.0                    5
# 10         Nigeria  Type A Charger    1725.0                    5
# 11    South Africa  Type A Charger     912.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1       mon2
# 6                 2.00 2021-09-01    2745.0  1098.00  1647.00  2021  September
# ...

# %%
filtering = df[df["mon2"].str.contains('mber')]
filtering
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 6           Zambia  Type A Charger     549.0                    5
# 7            Ghana  Type A Charger     788.0                    5
# 8            Ghana  Type A Charger    2472.0                    5
# 10         Nigeria  Type A Charger    1725.0                    5
# 11    South Africa  Type A Charger     912.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1       mon2
# 6                 2.00 2021-09-01    2745.0  1098.00  1647.00  2021  September
# ...

# %%
filtering.to_excel('Filter Output.xlsx', index = False)

# %%
df.query("Countries == 'Nigeria' and Products == 'Type A Charger'")
# Out:
#     Countries        Products  Quantity  Revenue per product  \
# 0     Nigeria  Type A Charger     292.0                    5
# 2     Nigeria  Type A Charger    2518.0                    5
# 10    Nigeria  Type A Charger    1725.0                    5
# 12    Nigeria  Type A Charger    2152.0                    5
# 13    Nigeria  Type A Charger    1817.0                    5
# ..        ...             ...       ...                  ...
# 834   Nigeria  Type A Charger     700.0                    5
# 835   Nigeria  Type A Charger    2222.0                    5
# 839   Nigeria  Type A Charger    1614.0                    5
# 842   Nigeria  Type A Charger    2559.0                    5
# 850   Nigeria  Type A Charger     723.0                    5
#
#      Cost per product Order Date  Revenues   Costs  Profit  mon1      mon2
# 0                 2.0 2022-02-01    1460.0   584.0   876.0  2022  February
# 2                 2.0 2022-06-01   12590.0  5036.0  7554.0  2022      June
# ...

# %%
df.query("Countries == 'Nigeria' and Revenues > 2000")
# Out:
#      Countries        Products  Quantity  Revenue per product  \
# 2      Nigeria  Type A Charger    2518.0                    5
# 10     Nigeria  Type A Charger    1725.0                    5
# 12     Nigeria  Type A Charger    2152.0                    5
# 13     Nigeria  Type A Charger    1817.0                    5
# 27     Nigeria  Type A Charger    2363.0                    5
# ...        ...             ...       ...                  ...
# 1308   Nigeria     Pin Charger    1269.0                    6
# 1319   Nigeria     Pin Charger    1916.0                    6
# 1321   Nigeria     Pin Charger     384.0                    6
# 1326   Nigeria     Pin Charger    1808.0                    6
# 1331   Nigeria     Pin Charger    2632.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1      mon2
# 2                 2.00 2022-06-01   12590.0  5036.00  7554.00  2022      June
# ...

# %%
df.query("Costs >= 1000 and Profit < 3000 and Products == 'Type A Charger'")
# Out:
#         Countries        Products  Quantity  Revenue per product  \
# 1           Ghana  Type A Charger     974.0                    5
# 5           Ghana  Type A Charger     883.0                    5
# 6          Zambia  Type A Charger     549.0                    5
# 7           Ghana  Type A Charger     788.0                    5
# 11   South Africa  Type A Charger     912.0                    5
# 20   South Africa  Type A Charger     727.0                    5
# 21         Zambia  Type A Charger     787.0                    5
# 23          Kenya  Type A Charger     747.0                    5
# 24          Kenya  Type A Charger     766.0                    5
# 28         Zambia  Type A Charger     918.0                    5
# 31          Ghana  Type A Charger     662.0                    5
# 33          Kenya  Type A Charger     809.0                    5
# 46          Kenya  Type A Charger     689.0                    5
# ...

# %%
df.query("Costs >= 1000 and Profit < 3000 and Products in('Type A Charger', 'Pin Charger')")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 1            Ghana  Type A Charger     974.0                    5
# 5            Ghana  Type A Charger     883.0                    5
# 6           Zambia  Type A Charger     549.0                    5
# 7            Ghana  Type A Charger     788.0                    5
# 11    South Africa  Type A Charger     912.0                    5
# ...            ...             ...       ...                  ...
# 1339  South Africa     Pin Charger     606.0                    6
# 1343         Ghana     Pin Charger     500.0                    6
# 1345        Zambia     Pin Charger     663.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1       mon2
# 1                 2.00 2022-02-01    4870.0  1948.00  2922.00  2022   February
# ...

# %%
df.query("Profit > 3000 and `Order Date` >= '2022-02-01' and `Order Date` <= '2022-02-01'")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 16          Zambia  Type A Charger    2296.0                    5
# 18    South Africa  Type A Charger    1514.0                    5
# 27         Nigeria  Type A Charger    2363.0                    5
# 73          Zambia  Type A Charger    1303.0                    5
# 166   South Africa  Type A Charger    2641.0                    5
# 167          Kenya  Type A Charger    2708.0                    5
# 295         Zambia  Type C Charger    2750.0                    5
# 312          Ghana  Type C Charger    1865.0                    5
# 320          Kenya  Type C Charger    1350.0                    5
# 352        Nigeria  Type C Charger    2240.0                    5
# 395   South Africa  Iphone Charger    1858.0                    4
# 419         Zambia  Iphone Charger    1865.0                    4
# 453        Nigeria  Iphone Charger    1937.0                    4
# ...

# %%
df.query("Profit > 3000 and mon2 in ('September', 'October', 'November')")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 8            Ghana  Type A Charger    2472.0                    5
# 9     South Africa  Type A Charger    1143.0                    5
# 10         Nigeria  Type A Charger    1725.0                    5
# 25    South Africa  Type A Charger    2905.0                    5
# 32         Nigeria  Type A Charger    1295.0                    5
# ...            ...             ...       ...                  ...
# 1326       Nigeria     Pin Charger    1808.0                    6
# 1328  South Africa     Pin Charger     986.0                    6
# 1336         Ghana     Pin Charger    2605.0                    6
# 1342         Kenya     Pin Charger    2536.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1       mon2
# 8                 2.00 2022-09-01   12360.0  4944.00  7416.00  2022  September
# ...

# %%
df.query("Profit > 3000 and `Order Date` > '2022-08-31' and `Order Date` > '202-08-31' ")
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 8            Ghana  Type A Charger    2472.0                    5
# 9     South Africa  Type A Charger    1143.0                    5
# 13         Nigeria  Type A Charger    1817.0                    5
# 14           Kenya  Type A Charger    1513.0                    5
# 25    South Africa  Type A Charger    2905.0                    5
# ...            ...             ...       ...                  ...
# 1315  South Africa     Pin Charger    1596.0                    6
# 1318         Kenya     Pin Charger    2665.0                    6
# 1326       Nigeria     Pin Charger    1808.0                    6
# 1328  South Africa     Pin Charger     986.0                    6
# 1337         Kenya     Pin Charger    1013.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1       mon2
# 8                 2.00 2022-09-01   12360.0  4944.00  7416.00  2022  September
# ...

# %% [markdown]
# # PIVOT TABLE

# %%
df.pivot_table(index = 'Products',
               aggfunc = 'sum')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df.pivot_table(index = 'Products',
#       2                aggfunc = 'sum')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9516, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9499 @Substitution("")
#    9500 @Appender(_shared_docs["pivot_table"])
#    9501 def pivot_table(
#    (...)
#    9512     sort: bool = True,
#    9513 ) -> DataFrame:
#    9514     from pandas.core.reshape.pivot import pivot_table
# -> 9516     return pivot_table(
#    9517         self,
#    9518         values=values,
#    9519         index=index,
#    9520         columns=columns,
#    9521         aggfunc=aggfunc,
#    9522         fill_value=fill_value,
#    9523         margins=margins,
#    9524         dropna=dropna,
# ...

# %%
df.pivot_table(index='Products',
               values=['Profit'],
               aggfunc='sum')
# Out:
#                     Profit
# Products
# Iphone Charger   734230.00
# Mini Charger     590740.50
# Pin Charger     1058729.75
# Type A Charger  1782202.50
# Type B Charger   246716.80
# Type C Charger   869764.00

# %%
df.pivot_table(index='Products',
               values=['Revenues'],
               aggfunc='sum')
# Out:
#                  Revenues
# Products
# Iphone Charger  1174768.0
# Mini Charger    1012698.0
# Pin Charger     1954578.0
# Type A Charger  2970337.5
# Type B Charger   308396.0
# Type C Charger  1553150.0

# %%
df.pivot_table(index='Products',
               values=['Profit', 'Revenues'],
               aggfunc='sum')
# Out:
#                     Profit   Revenues
# Products
# Iphone Charger   734230.00  1174768.0
# Mini Charger     590740.50  1012698.0
# Pin Charger     1058729.75  1954578.0
# Type A Charger  1782202.50  2970337.5
# Type B Charger   246716.80   308396.0
# Type C Charger   869764.00  1553150.0

# %%
df.pivot_table(index='Products',
               columns= 'Countries',
               values=['Profit', 'Revenues'],
               aggfunc='sum')
# Out:
#                   Profit                                               \
# Countries          Ghana     Kenya    Nigeria South Africa     Zambia
# Products
# Iphone Charger  136120.0  124720.0  174020.00     129090.0  170280.00
# Mini Charger     91451.5  108958.5  144369.75     120750.0  125210.75
# Pin Charger     172510.0  201825.0  211016.00     235417.0  237961.75
# Type A Charger  347199.0  300741.0  398823.00     362370.0  373069.50
# Type B Charger   50806.4   44897.6   50381.60      50580.0   50051.20
# Type C Charger  159017.6  171441.2  163699.20     198629.2  176976.80
#
#                 Revenues
# Countries          Ghana     Kenya   Nigeria South Africa    Zambia
# Products
# Iphone Charger  217792.0  199552.0  278432.0     206544.0  272448.0
# Mini Charger    156774.0  186786.0  247491.0     207000.0  214647.0
# Pin Charger     318480.0  372600.0  389568.0     434616.0  439314.0
# Type A Charger  578665.0  501235.0  664705.0     603950.0  621782.5
# ...

# %%
df.pivot_table(index='mon2',
               values=['Profit', 'Revenues'],
               aggfunc='sum')
# Out:
#               Profit   Revenues
# mon2
# April      380024.25   644246.5
# August     304065.40   519095.0
# December   708866.90  1202583.0
# February   249619.50   426655.0
# January    323473.00   551769.5
# July       337161.10   574497.5
# June       468624.90   798686.0
# March      253644.10   429272.0
# May        242685.70   413352.0
# November   557693.20   943347.0
# October    938637.30  1591504.0
# September  517888.20   878920.0

# %%
df.pivot_table(index='Countries',
               columns = 'Products',
               values=['Profit', 'Revenues'],
               aggfunc='sum')
# Out:
#                      Profit                                          \
# Products     Iphone Charger Mini Charger Pin Charger Type A Charger
# Countries
# Ghana              136120.0     91451.50   172510.00       347199.0
# Kenya              124720.0    108958.50   201825.00       300741.0
# Nigeria            174020.0    144369.75   211016.00       398823.0
# South Africa       129090.0    120750.00   235417.00       362370.0
# Zambia             170280.0    125210.75   237961.75       373069.5
#
#                                                  Revenues               \
# Products     Type B Charger Type C Charger Iphone Charger Mini Charger
# Countries
# Ghana               50806.4       159017.6       217792.0     156774.0
# Kenya               44897.6       171441.2       199552.0     186786.0
# Nigeria             50381.6       163699.2       278432.0     247491.0
# South Africa        50580.0       198629.2       206544.0     207000.0
# ...

# %%
df.pivot_table(index='Countries',
               columns = 'Products',
               values=['Profit', 'Revenues'],
               aggfunc='count')
# Out:
#                      Profit                                          \
# Products     Iphone Charger Mini Charger Pin Charger Type A Charger
# Countries
# Ghana                    36           40          44             72
# Kenya                    40           44          44             70
# Nigeria                  40           44          40             72
# South Africa             34           46          47             70
# Zambia                   36           44          44             69
#
#                                                  Revenues               \
# Products     Type B Charger Type C Charger Iphone Charger Mini Charger
# Countries
# Ghana                    40             40             36           40
# Kenya                    36             36             40           44
# Nigeria                  36             36             40           44
# South Africa             34             40             34           46
# ...

# %%
df.pivot_table(index='mon2',
               values=['Profit', 'Revenues'],
               aggfunc='sum')
# Out:
#               Profit   Revenues
# mon2
# April      380024.25   644246.5
# August     304065.40   519095.0
# December   708866.90  1202583.0
# February   249619.50   426655.0
# January    323473.00   551769.5
# July       337161.10   574497.5
# June       468624.90   798686.0
# March      253644.10   429272.0
# May        242685.70   413352.0
# November   557693.20   943347.0
# October    938637.30  1591504.0
# September  517888.20   878920.0

# %%
f_pivot = df.pivot_table(index='mon2',
               values=['Profit', 'Revenues'],
               aggfunc='sum')
f_pivot.sort_values( by = ['mon2'], ascending = False)
# Out:
#               Profit   Revenues
# mon2
# September  517888.20   878920.0
# October    938637.30  1591504.0
# November   557693.20   943347.0
# May        242685.70   413352.0
# March      253644.10   429272.0
# June       468624.90   798686.0
# July       337161.10   574497.5
# January    323473.00   551769.5
# February   249619.50   426655.0
# December   708866.90  1202583.0
# August     304065.40   519095.0
# April      380024.25   644246.5

# %%
df
# Out:
#          Countries        Products  Quantity  Revenue per product  \
# 0          Nigeria  Type A Charger     292.0                    5
# 1            Ghana  Type A Charger     974.0                    5
# 2          Nigeria  Type A Charger    2518.0                    5
# 3            Kenya  Type A Charger    1006.0                    5
# 4            Kenya  Type A Charger     367.0                    5
# ...            ...             ...       ...                  ...
# 1345        Zambia     Pin Charger     663.0                    6
# 1346  South Africa     Pin Charger    2574.0                    6
# 1347  South Africa     Pin Charger    2438.0                    6
# 1348  South Africa     Pin Charger     914.0                    6
# 1349  South Africa     Pin Charger     914.0                    6
#
#       Cost per product Order Date  Revenues    Costs   Profit  mon1       mon2
# 0                 2.00 2022-02-01    1460.0   584.00   876.00  2022   February
# ...

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']

# Convert 'mon2' to ordered categorical
df['mon2'] = pd.Categorical(df['mon2'], categories=month_order, ordered=True)

# Create the pivot
f_pivot = df.pivot_table(index='mon2',
                         values=['Profit', 'Revenues'],
                         aggfunc='sum',
                        observed = False)

# Sort by calendar month
f_pivot = f_pivot.sort_index()
f_pivot
# Out:
#               Profit   Revenues
# mon2
# January    323473.00   551769.5
# February   249619.50   426655.0
# March      253644.10   429272.0
# April      380024.25   644246.5
# May        242685.70   413352.0
# June       468624.90   798686.0
# July       337161.10   574497.5
# August     304065.40   519095.0
# September  517888.20   878920.0
# October    938637.30  1591504.0
# November   557693.20   943347.0
# December   708866.90  1202583.0

# %%
df.pivot_table(index = 'Products',
               values = 'Profit',
               aggfunc = 'sum')
# Out:
#                     Profit
# Products
# Iphone Charger   734230.00
# Mini Charger     590740.50
# Pin Charger     1058729.75
# Type A Charger  1782202.50
# Type B Charger   246716.80
# Type C Charger   869764.00

# %%
barchart = df.pivot_table(index = 'Products',
               values = 'Profit',
               aggfunc = 'sum')

barchart.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Products'>

# %%
from matplotlib import pyplot as plt
barchart = df.pivot_table(index = 'Products',
               values = 'Profit',
               aggfunc = 'sum')

barchart.plot(kind = 'barh')

plt.title('Profit by products')
# Out:
# Text(0.5, 1.0, 'Profit by products')

# %%
from matplotlib import pyplot as plt
piechart = df.pivot_table(index = 'Countries',
               values = 'Revenues',
               aggfunc = 'sum')

piechart.plot(kind = 'pie', y = 'Revenues', autopct = '%1.0f%%')

plt.title('Profit by products')
# Out:
# Text(0.5, 1.0, 'Profit by products')

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']

# Convert 'mon2' to ordered categorical
df['mon2'] = pd.Categorical(df['mon2'], categories=month_order, ordered=True)

# Create the pivot
dftable = df.pivot_table(index='mon2',
                         values='Profit',
                         aggfunc='sum',
                        observed = False)
dftable.plot(kind = 'bar')

# Sort by calendar month
#f_pivot = f_pivot.sort_index()
#f_pivot
# Out:
# <Axes: xlabel='mon2'>

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']

# Convert 'mon2' to ordered categorical
df['mon2'] = pd.Categorical(df['mon2'], categories=month_order, ordered=True)

# Create the pivot
dftable = df.pivot_table(index='mon2',
                         values='Profit',
                         aggfunc='sum',
                        observed = False)
dftable.plot(kind = 'line', color ='red')

# Sort by calendar month
#f_pivot = f_pivot.sort_index()
#f_pivot
# Out:
# <Axes: xlabel='mon2'>

# %%
from matplotlib import pyplot as plt
month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']

# Convert 'mon2' to ordered categorical
df['mon2'] = pd.Categorical(df['mon2'], categories=month_order, ordered=True)

# Create the pivot
dftable = df.pivot_table(index='mon2',
                         values='Profit',
                         aggfunc='sum',
                        observed = False)
dftable.plot.area()

plt.savefig('areacgart.png')

# Sort by calendar month
#f_pivot = f_pivot.sort_index()
#f_pivot
